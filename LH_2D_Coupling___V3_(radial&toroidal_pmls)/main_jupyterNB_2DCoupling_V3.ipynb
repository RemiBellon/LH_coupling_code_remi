# %%
# %load_ext autoreload
# %autoreload 2

# Importing the modules

    
import config_2Dcoupling_V3 as cfg              # config = physical & simulation parameters 
from solver_Hcurl_2D_V3 import *                # solver = mesh build, physics import and FEM method + pmls initialization
import Post_Process_V3_Run_n_Save as pp_run     # post process run and save = run scan function and save data in H5 files
import Post_Process_V3_Load_n_Plot as pp_plot   # post process load and plot = recover the sim data from H5 files and plot graphs "instantly"

# %%
solver = LHCouplingSolver_2DHcurl_1DH1(cfg.__dict__)

# %%
mesh_save_dir = Path("/Home/RB286887/LH_coupling_code_remi/LH_2D_Coupling___V3_(radial&toroidal_pmls)/Meshes")
mesh_save_dir.mkdir(parents=True, exist_ok=True)

figure_save_dir = Path("/Home/RB286887/LH_coupling_code_remi/LH_2D_Coupling___V3_(radial&toroidal_pmls)/Figures")
figure_save_dir.mkdir(parents=True, exist_ok=True)


solver.build_physics_Stix_B_field(lambda x, z: pp_run.create_density_profile(x, z, solver))
mesh = solver.build_mesh_with_PMLs(mesh_save_dir)
# print('num_vertices = ', mesh.nv)

GF_E_field, _ = solver.solve_helmholtz_Hcurl_2D_pml(mesh, cfg)
# Out:
# ne = 3e+18, type(ne) = <class 'float'>
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 6.94753e+00, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 1.16624e-02 m, lambda_para = -4.05125e-02 m
#   --> Lx_plasma = 9.00e-02 m , Lx_pml = 1.00e-02 m, Lx_tot = 1.00e-01 m
#   --> Lz_plasma = 5.00e-01 m , Lz_pml = 3.00e-02 m, Lz_tot = 5.60e-01 m
#   --> h_max resolution : 1.45780e-03 m
# #DoFs = 580612 (= number of mesh points).
# --- Solving the 3D vector linear system ---
#   --> Success | Gamma_Radial: 9.71e-01 | Gamma_Toroidal: 3.43e-01
# --- System solved ---

# %%
# Create the Run_XXX_XXX file in Simulation_Results folder
# run_folder = /Simulation_Results/Run_XXX
run_folder_path = pp_run.setup_output_directory("Simulation_Results", save_data=True)

# Total Run_XXX folder path to Remi's shared zone (cea intra) 
run_folder_tot_path = '/Home/RB286887/LH_coupling_code_remi/LH_2D_Coupling___V3_(radial&toroidal_pmls)/' + run_folder_path
print(f'sim_target_folder: {run_folder_tot_path}')
# Out:
# [SYSTEM] Output directory created: Simulation_Results/Run_20260526_160640
# sim_target_folder: /Home/RB286887/LH_coupling_code_remi/LH_2D_Coupling___V3_(radial&toroidal_pmls)/Simulation_Results/Run_20260526_160640

# %%
# --- Post-treatment: --- 
# Generate the H5 file for 2D map plot and save it in Run_XXX folder 
E_map2D_h5_filepath = pp_run.run_2D_wave_map(mesh, GF_E_field, cfg, run_folder_tot_path)
# --- Post-treatment: --- )
# Plot E field 2D map and save it in the same folder: Run_XXX 
pp_plot.plot_2D_wave_map(E_map2D_h5_filepath, run_folder_tot_path, component='Ez', value_type='real', plot_e_vectors=False)
# Out:
# --- Extracting 2D Wave Map ---
# params recover in run_2D_wave_map
# Params recovered
# h5_path = /Home/RB286887/LH_coupling_code_remi/LH_2D_Coupling___V3_(radial&toroidal_pmls)/Simulation_Results/Run_20260526_160640/Wave_Map_2D.h5
# type(h5_path) = <class 'str'>
# oui
# --- 2D Map saved to /Home/RB286887/LH_coupling_code_remi/LH_2D_Coupling___V3_(radial&toroidal_pmls)/Simulation_Results/Run_20260526_160640/Wave_Map_2D.h5 ---
# --- Plotting 2D Map from /Home/RB286887/LH_coupling_code_remi/LH_2D_Coupling___V3_(radial&toroidal_pmls)/Simulation_Results/Run_20260526_160640/Wave_Map_2D.h5 ---

# %%
# E_radial_profile_h5_filepath = pp_run.run_1D_radial_profile(mesh, GF_E_field, cfg, run_folder_tot_path)
# pp_plot.plot_1D_radial_benchmark(E_radial_profile_h5_filepath, run_folder_tot_path, component='Ex')
# pp_plot.plot_1D_radial_benchmark(E_radial_profile_h5_filepath, run_folder_tot_path, component='Ey')
# pp_plot.plot_1D_radial_benchmark(E_radial_profile_h5_filepath, run_folder_tot_path, component='Ez')

# %%
h5_file_path = pp_run.run_pml_scan_dataset(solver, cfg, run_folder_tot_path)
# Out:
# --- Initiating ULTIMATE 7D Sobol Data Lake: 4096 Simulations ---
#
#
#
#
# Run 1/4096 | S_i:1.0, L:8.6λ, p:2.2, n//:48.47, ne:8.2e+17
#
#
# --- delta = 127617101.93211007 ---
# --- B_stix = -6578.339559791097, S = 1.0048314465815358, C_stix = -20984253.342969418 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 9.43111e+01, n_perp_m = 1.00000e-03
#   --> lambda_perp : 8.59125e-04 m, lambda_para = 1.67182e-03 m
#   --> Lx_plm = 7.39282e-03 m, Lx_tot = 9.11107e-03 m
#   --> Lz_exact: 1.67182e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 9.42121e+01, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 8.60028e-04 m, lambda_para = 1.67182e-03 m
#   --> Lx_plm = 7.39282e-03 m, Lx_tot = 9.11107e-03 m
#   --> Lz_exact : 1.67182e-03 m
#   --> h_max resolution : 1.07503e-04 m
# #DoFs = 28588 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 2.1500 ---
# coeff gamma =  0.3650777760624413
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 3.63e-01
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 2/4096 | S_i:6.4, L:1.1λ, p:2.4, n//:85.72, ne:2.0e+19
#
#
# --- delta = 738448041975.3109 ---
# --- B_stix = -842910.9485667355, S = 1.1174590939668214, C_stix = -6252840688.427683 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 8.72730e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 9.28409e-05 m, lambda_para = 9.45251e-04 m
#   --> Lx_plm = 1.05484e-04 m, Lx_tot = 2.91165e-04 m
#   --> Lz_exact: 9.45251e-04 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 8.72038e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 9.29146e-05 m, lambda_para = 9.45251e-04 m
#   --> Lx_plm = 1.05484e-04 m, Lx_tot = 2.91165e-04 m
#   --> Lz_exact : 9.45251e-04 m
#   --> h_max resolution : 1.16143e-05 m
# #DoFs = 44421 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0026 ---
# coeff gamma =  0.00129207711074746
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 1.28e-03
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 3/4096 | S_i:3.8, L:7.6λ, p:1.8, n//:66.67, ne:1.2e+19
#
#
# --- delta = 94127740622.70084 ---
# --- B_stix = -297297.3586896622, S = 1.0693190334321296, C_stix = -1342448081.285282 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 5.31479e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 1.52452e-04 m, lambda_para = 1.21524e-03 m
#   --> Lx_plm = 1.16623e-03 m, Lx_tot = 1.47114e-03 m
#   --> Lz_exact: 1.21524e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 5.31045e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 1.52577e-04 m, lambda_para = 1.21524e-03 m
#   --> Lx_plm = 1.16623e-03 m, Lx_tot = 1.47114e-03 m
#   --> Lz_exact : 1.21524e-03 m
#   --> h_max resolution : 1.90721e-05 m
# #DoFs = 110108 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0050 ---
# coeff gamma =  0.0025003616661820475
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 2.41e-03
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 4/4096 | S_i:1.2, L:4.6λ, p:2.7, n//:4.26, ne:4.4e+18
#
#
# --- delta = 196976.3924134881 ---
# --- B_stix = -408.69218373769957, S = 1.0260639997334668, C_stix = -7296.594406630011 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 2.03821e+01, n_perp_m = 1.00000e-03
#   --> lambda_perp : 3.97531e-03 m, lambda_para = 1.90140e-02 m
#   --> Lx_plm = 1.83241e-02 m, Lx_tot = 2.62747e-02 m
#   --> Lz_exact: 1.90140e-02 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 2.03647e+01, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 3.97870e-03 m, lambda_para = 1.90140e-02 m
#   --> Lx_plm = 1.83241e-02 m, Lx_tot = 2.62747e-02 m
#   --> Lz_exact : 1.90140e-02 m
#   --> h_max resolution : 4.97338e-04 m
# #DoFs = 44783 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0458 ---
# coeff gamma =  0.022364076481108504
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 2.22e-02
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 5/4096 | S_i:1.8, L:5.9λ, p:3.0, n//:23.75, ne:1.1e+18
#
#
# --- delta = 12394371.71485069 ---
# --- B_stix = -2387.6758372020454, S = 1.0062802956644479, C_stix = -1662900.4463593715 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 5.41819e+01, n_perp_m = 1.00000e-03
#   --> lambda_perp : 1.49542e-03 m, lambda_para = 3.41205e-03 m
#   --> Lx_plm = 8.78925e-03 m, Lx_tot = 1.17801e-02 m
#   --> Lz_exact: 3.41205e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 5.41283e+01, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 1.49690e-03 m, lambda_para = 3.41205e-03 m
#   --> Lx_plm = 8.78925e-03 m, Lx_tot = 1.17801e-02 m
#   --> Lz_exact : 3.41205e-03 m
#   --> h_max resolution : 1.87113e-04 m
# #DoFs = 25505 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 2.4239 ---
# coeff gamma =  0.4158715492853928
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 4.04e-01
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 6/4096 | S_i:2.6, L:3.9λ, p:1.5, n//:61.00, ne:4.9e+19
#
#
# --- delta = 1135414340066.0415 ---
# --- B_stix = -1055977.7796532358, S = 1.2876774294235631, C_stix = -3946110353.460623 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 9.07625e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 8.92714e-05 m, lambda_para = 1.32828e-03 m
#   --> Lx_plm = 3.44095e-04 m, Lx_tot = 5.22637e-04 m
#   --> Lz_exact: 1.32828e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 9.06958e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 8.93371e-05 m, lambda_para = 1.32828e-03 m
#   --> Lx_plm = 3.44095e-04 m, Lx_tot = 5.22637e-04 m
#   --> Lz_exact : 1.32828e-03 m
#   --> h_max resolution : 1.11671e-05 m
# #DoFs = 121044 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0010 ---
# coeff gamma =  0.0004917524715405147
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 4.89e-04
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 7/4096 | S_i:9.9, L:9.4λ, p:2.4, n//:91.39, ne:8.5e+18
#
#
# --- delta = 176628514269.42017 ---
# --- B_stix = -402724.8126620472, S = 1.0505318820763125, C_stix = -3436649515.8616443 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 6.25863e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 1.29461e-04 m, lambda_para = 8.86563e-04 m
#   --> Lx_plm = 1.22080e-03 m, Lx_tot = 1.47973e-03 m
#   --> Lz_exact: 8.86563e-04 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 6.25345e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 1.29569e-04 m, lambda_para = 8.86563e-04 m
#   --> Lx_plm = 1.22080e-03 m, Lx_tot = 1.47973e-03 m
#   --> Lz_exact : 8.86563e-04 m
#   --> h_max resolution : 1.61961e-05 m
# #DoFs = 110057 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0072 ---
# coeff gamma =  0.0035875378997148677
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 3.54e-03
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 8/4096 | S_i:0.7, L:2.8λ, p:2.0, n//:28.98, ne:1.9e+18
#
#
# --- delta = 88005006.92348562 ---
# --- B_stix = -7684.605713939392, S = 1.0112302853761517, C_stix = -7157578.833293726 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 9.18591e+01, n_perp_m = 1.00000e-03
#   --> lambda_perp : 8.82058e-04 m, lambda_para = 2.79592e-03 m
#   --> Lx_plm = 2.50298e-03 m, Lx_tot = 4.26709e-03 m
#   --> Lz_exact: 2.79592e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 9.17755e+01, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 8.82861e-04 m, lambda_para = 2.79592e-03 m
#   --> Lx_plm = 2.50298e-03 m, Lx_tot = 4.26709e-03 m
#   --> Lz_exact : 2.79592e-03 m
#   --> h_max resolution : 1.10358e-04 m
# #DoFs = 21791 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.1235 ---
# coeff gamma =  0.05815295002861573
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 5.64e-02
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 9/4096 | S_i:0.5, L:7.0λ, p:1.6, n//:78.92, ne:3.6e+18
#
#
# --- delta = 17183911521.79585 ---
# --- B_stix = -118370.73761313001, S = 1.021139837340067, C_stix = -776651708.884148 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 3.49495e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 2.31834e-04 m, lambda_para = 1.02673e-03 m
#   --> Lx_plm = 1.62193e-03 m, Lx_tot = 2.08560e-03 m
#   --> Lz_exact: 1.02673e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 3.49193e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 2.32035e-04 m, lambda_para = 1.02673e-03 m
#   --> Lx_plm = 1.62193e-03 m, Lx_tot = 2.08560e-03 m
#   --> Lz_exact : 1.02673e-03 m
#   --> h_max resolution : 2.90044e-05 m
# #DoFs = 56510 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0462 ---
# coeff gamma =  0.022580299166411404
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 2.15e-02
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 10/4096 | S_i:7.1, L:5.0λ, p:2.9, n//:41.66, ne:1.4e+19
#
#
# --- delta = 21795941510.934307 ---
# --- B_stix = -143868.34030794725, S = 1.0854642041797558, C_stix = -252850845.68969882 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 3.66436e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 2.21116e-04 m, lambda_para = 1.94478e-03 m
#   --> Lx_plm = 1.09966e-03 m, Lx_tot = 1.54189e-03 m
#   --> Lz_exact: 1.94478e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 3.66140e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 2.21295e-04 m, lambda_para = 1.94478e-03 m
#   --> Lx_plm = 1.09966e-03 m, Lx_tot = 1.54189e-03 m
#   --> Lz_exact : 1.94478e-03 m
#   --> h_max resolution : 2.76619e-05 m
# #DoFs = 85599 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0031 ---
# coeff gamma =  0.001565058282232205
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 1.52e-03
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 11/4096 | S_i:2.9, L:8.3λ, p:1.9, n//:11.26, ne:2.5e+19
#
#
# --- delta = 338831931.5540275 ---
# --- B_stix = -18119.30475837962, S = 1.1474247457583293, C_stix = -2292683.3907601256 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 1.26162e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 6.42230e-04 m, lambda_para = 7.19797e-03 m
#   --> Lx_plm = 5.33808e-03 m, Lx_tot = 6.62254e-03 m
#   --> Lz_exact: 7.19797e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 1.26063e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 6.42732e-04 m, lambda_para = 7.19797e-03 m
#   --> Lx_plm = 5.33808e-03 m, Lx_tot = 6.62254e-03 m
#   --> Lz_exact : 7.19797e-03 m
#   --> h_max resolution : 8.03415e-05 m
# #DoFs = 164128 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0008 ---
# coeff gamma =  0.00040930219139085017
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 4.03e-04
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 12/4096 | S_i:1.9, L:1.7λ, p:2.5, n//:73.67, ne:6.5e+17
#
#
# --- delta = 432686289.8132331 ---
# --- B_stix = -9906.909599751247, S = 1.0038493363778298, C_stix = -83314153.79590274 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 1.23674e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 6.55152e-04 m, lambda_para = 1.09984e-03 m
#   --> Lx_plm = 1.12653e-03 m, Lx_tot = 2.43684e-03 m
#   --> Lz_exact: 1.09984e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 1.23534e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 6.55891e-04 m, lambda_para = 1.09984e-03 m
#   --> Lx_plm = 1.12653e-03 m, Lx_tot = 2.43684e-03 m
#   --> Lz_exact : 1.09984e-03 m
#   --> h_max resolution : 8.19864e-05 m
# #DoFs = 8823 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.6864 ---
# coeff gamma =  0.2554967302479775
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 2.56e-01
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 13/4096 | S_i:1.4, L:9.7λ, p:2.3, n//:54.18, ne:2.8e+18
#
#
# --- delta = 2345454174.7929196 ---
# --- B_stix = -42462.75574265949, S = 1.016569766727522, C_stix = -133382028.28865284 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 2.11437e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 3.83211e-04 m, lambda_para = 1.49536e-03 m
#   --> Lx_plm = 3.72940e-03 m, Lx_tot = 4.49582e-03 m
#   --> Lz_exact: 1.49536e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 2.11251e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 3.83549e-04 m, lambda_para = 1.49536e-03 m
#   --> Lx_plm = 3.72940e-03 m, Lx_tot = 4.49582e-03 m
#   --> Lz_exact : 1.49536e-03 m
#   --> h_max resolution : 4.79436e-05 m
# #DoFs = 65853 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0497 ---
# coeff gamma =  0.02426182404689891
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 2.32e-02
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 14/4096 | S_i:4.0, L:2.3λ, p:2.2, n//:16.93, ne:5.8e+18
#
#
# --- delta = 94874003.71463497 ---
# --- B_stix = -9149.450317757892, S = 1.0342489624553475, C_stix = -2697987.3808664493 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 9.55621e+01, n_perp_m = 1.00000e-03
#   --> lambda_perp : 8.47877e-04 m, lambda_para = 4.78566e-03 m
#   --> Lx_plm = 1.91885e-03 m, Lx_tot = 3.61461e-03 m
#   --> Lz_exact: 4.78566e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 9.54816e+01, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 8.48593e-04 m, lambda_para = 4.78566e-03 m
#   --> Lx_plm = 1.91885e-03 m, Lx_tot = 3.61461e-03 m
#   --> Lz_exact : 4.78566e-03 m
#   --> h_max resolution : 1.06074e-04 m
# #DoFs = 33304 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0065 ---
# coeff gamma =  0.0032605754893366406
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 3.25e-03
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 15/4096 | S_i:5.0, L:6.5λ, p:2.8, n//:35.99, ne:3.5e+19
#
#
# --- delta = 70316589067.62408 ---
# --- B_stix = -262051.62934172063, S = 1.2058196433595343, C_stix = -341164749.6446767 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 4.67565e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 1.73292e-04 m, lambda_para = 2.25141e-03 m
#   --> Lx_plm = 1.13028e-03 m, Lx_tot = 1.47686e-03 m
#   --> Lz_exact: 2.25141e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 4.67209e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 1.73423e-04 m, lambda_para = 2.25141e-03 m
#   --> Lx_plm = 1.13028e-03 m, Lx_tot = 1.47686e-03 m
#   --> Lz_exact : 2.25141e-03 m
#   --> h_max resolution : 2.16779e-05 m
# #DoFs = 155464 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0005 ---
# coeff gamma =  0.00022840856779348526
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 2.27e-04
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 16/4096 | S_i:0.7, L:3.5λ, p:1.7, n//:98.40, ne:1.5e+18
#
#
# --- delta = 7163636811.6012 ---
# --- B_stix = -65104.671710233946, S = 1.00877822593315, C_stix = -724891373.0265477 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 2.72433e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 2.97412e-04 m, lambda_para = 8.23414e-04 m
#   --> Lx_plm = 1.03558e-03 m, Lx_tot = 1.63040e-03 m
#   --> Lz_exact: 8.23414e-04 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 2.72178e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 2.97691e-04 m, lambda_para = 8.23414e-04 m
#   --> Lx_plm = 1.03558e-03 m, Lx_tot = 1.63040e-03 m
#   --> Lz_exact : 8.23414e-04 m
#   --> h_max resolution : 3.72114e-05 m
# #DoFs = 21364 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.4743 ---
# coeff gamma =  0.19167827831938106
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 1.95e-01
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 17/4096 | S_i:0.9, L:6.1λ, p:2.5, n//:1.25, ne:5.7e+18
#
#
# --- delta = 78.41223863027824 ---
# --- B_stix = -15.217586491894089, S = 1.033559625577388, C_stix = 37.047378839521805 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 3.41255e+00, n_perp_m = 1.75441e+00
#   --> lambda_perp : 2.37432e-02 m, lambda_para = 6.47811e-02 m
#   --> Lx_plm = 1.45314e-01 m, Lx_tot = 1.92801e-01 m
#   --> Lz_exact: 6.47811e-02 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 3.41096e+00, n_perp_m = 1.75080e+00
#   --> SW lambda_perp : 2.37543e-02 m, lambda_para = 6.47811e-02 m
#   --> Lx_plm = 1.45314e-01 m, Lx_tot = 1.92801e-01 m
#   --> Lz_exact : 6.47811e-02 m
#   --> h_max resolution : 2.96929e-03 m
# #DoFs = 32204 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.2887 ---
# coeff gamma =  0.12613077930057737
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 1.26e-01
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 18/4096 | S_i:5.4, L:3.6λ, p:2.0, n//:63.66, ne:2.2e+18
#
#
# --- delta = 2665865851.900833 ---
# --- B_stix = -43424.254107696346, S = 1.0127951227281444, C_stix = -192585842.28502265 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 2.16628e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 3.74028e-04 m, lambda_para = 1.27271e-03 m
#   --> Lx_plm = 1.34922e-03 m, Lx_tot = 2.09728e-03 m
#   --> Lz_exact: 1.27271e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 2.16433e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 3.74365e-04 m, lambda_para = 1.27271e-03 m
#   --> Lx_plm = 1.34922e-03 m, Lx_tot = 2.09728e-03 m
#   --> Lz_exact : 1.27271e-03 m
#   --> h_max resolution : 4.67956e-05 m
# #DoFs = 26942 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0647 ---
# coeff gamma =  0.0313289987310078
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 3.17e-02
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 19/4096 | S_i:4.7, L:9.6λ, p:2.9, n//:82.72, ne:1.2e+18
#
#
# --- delta = 2508536337.002612 ---
# --- B_stix = -36301.59489240056, S = 1.0073510953585574, C_stix = -295510311.8359197 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 2.07071e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 3.91292e-04 m, lambda_para = 9.79512e-04 m
#   --> Lx_plm = 3.75905e-03 m, Lx_tot = 4.54164e-03 m
#   --> Lz_exact: 9.79512e-04 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 2.06871e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 3.91668e-04 m, lambda_para = 9.79512e-04 m
#   --> Lx_plm = 3.75905e-03 m, Lx_tot = 4.54164e-03 m
#   --> Lz_exact : 9.79512e-04 m
#   --> h_max resolution : 4.89585e-05 m
# #DoFs = 40447 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.4204 ---
# coeff gamma =  0.17368832102325488
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 1.79e-01
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 20/4096 | S_i:1.5, L:2.7λ, p:1.5, n//:45.47, ne:3.1e+19
#
#
# --- delta = 141197036493.73407 ---
# --- B_stix = -370874.7211894023, S = 1.1826529198849944, C_stix = -771354303.3344127 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 5.61838e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 1.44214e-04 m, lambda_para = 1.78209e-03 m
#   --> Lx_plm = 3.84354e-04 m, Lx_tot = 6.72782e-04 m
#   --> Lz_exact: 1.78209e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 5.61406e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 1.44325e-04 m, lambda_para = 1.78209e-03 m
#   --> Lx_plm = 3.84354e-04 m, Lx_tot = 6.72782e-04 m
#   --> Lz_exact : 1.78209e-03 m
#   --> h_max resolution : 1.80406e-05 m
# #DoFs = 78733 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0045 ---
# coeff gamma =  0.0022243856421463575
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 2.19e-03
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 21/4096 | S_i:2.2, L:7.9λ, p:1.9, n//:25.98, ne:1.3e+19
#
#
# --- delta = 2567300497.4820232 ---
# --- B_stix = -49218.717267871754, S = 1.075505461951023, C_stix = -33662862.04735258 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 2.15493e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 3.75998e-04 m, lambda_para = 3.11864e-03 m
#   --> Lx_plm = 2.95748e-03 m, Lx_tot = 3.70947e-03 m
#   --> Lz_exact: 3.11864e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 2.15318e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 3.76304e-04 m, lambda_para = 3.11864e-03 m
#   --> Lx_plm = 2.95748e-03 m, Lx_tot = 3.70947e-03 m
#   --> Lz_exact : 3.11864e-03 m
#   --> h_max resolution : 4.70379e-05 m
# #DoFs = 115771 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0081 ---
# coeff gamma =  0.004028130229367689
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 3.95e-03
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 22/4096 | S_i:3.0, L:1.9λ, p:2.7, n//:88.39, ne:3.0e+18
#
#
# --- delta = 19142479883.0051 ---
# --- B_stix = -122453.52268693011, S = 1.0177831211940045, C_stix = -1018786462.99932 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 3.57948e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 2.26360e-04 m, lambda_para = 9.16636e-04 m
#   --> Lx_plm = 4.23557e-04 m, Lx_tot = 8.76277e-04 m
#   --> Lz_exact: 9.16636e-04 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 3.57634e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 2.26558e-04 m, lambda_para = 9.16636e-04 m
#   --> Lx_plm = 4.23557e-04 m, Lx_tot = 8.76277e-04 m
#   --> Lz_exact : 9.16636e-04 m
#   --> h_max resolution : 2.83198e-05 m
# #DoFs = 21634 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0969 ---
# coeff gamma =  0.04620242463551488
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 4.43e-02
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 23/4096 | S_i:8.0, L:6.8λ, p:2.1, n//:57.99, ne:5.0e+17
#
#
# --- delta = 99928191.05912241 ---
# --- B_stix = -3252.832412654294, S = 1.0029858971981482, C_stix = -22270321.198907334 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 8.12705e+01, n_perp_m = 1.00000e-03
#   --> lambda_perp : 9.96979e-04 m, lambda_para = 1.39724e-03 m
#   --> Lx_plm = 6.82385e-03 m, Lx_tot = 8.81781e-03 m
#   --> Lz_exact: 1.39724e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 8.11685e+01, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 9.98231e-04 m, lambda_para = 1.39724e-03 m
#   --> Lx_plm = 6.82385e-03 m, Lx_tot = 8.81781e-03 m
#   --> Lz_exact : 1.39724e-03 m
#   --> h_max resolution : 1.24779e-04 m
# #DoFs = 18423 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 5.9909 ---
# coeff gamma =  0.7139120905180026
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 7.07e-01
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 24/4096 | S_i:0.6, L:5.4λ, p:2.4, n//:20.74, ne:2.4e+19
#
#
# --- delta = 3769091171.6953087 ---
# --- B_stix = -60411.603107196446, S = 1.1438117177672635, C_stix = -26125231.07107276 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 2.30749e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 3.51139e-04 m, lambda_para = 3.90741e-03 m
#   --> Lx_plm = 1.90288e-03 m, Lx_tot = 2.60516e-03 m
#   --> Lz_exact: 3.90741e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 2.30568e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 3.51414e-04 m, lambda_para = 3.90741e-03 m
#   --> Lx_plm = 1.90288e-03 m, Lx_tot = 2.60516e-03 m
#   --> Lz_exact : 3.90741e-03 m
#   --> h_max resolution : 4.39268e-05 m
# #DoFs = 115045 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0289 ---
# coeff gamma =  0.014232102186465334
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 1.42e-02
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 25/4096 | S_i:0.6, L:9.0λ, p:2.8, n//:70.48, ne:3.8e+19
#
#
# --- delta = 1229047559582.324 ---
# --- B_stix = -1096465.1963752958, S = 1.2241862008024247, C_stix = -5475399228.980375 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 9.49018e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 8.53777e-05 m, lambda_para = 1.14966e-03 m
#   --> Lx_plm = 7.68139e-04 m, Lx_tot = 9.38895e-04 m
#   --> Lz_exact: 1.14966e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 9.48302e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 8.54422e-05 m, lambda_para = 1.14966e-03 m
#   --> Lx_plm = 7.68139e-04 m, Lx_tot = 9.38895e-04 m
#   --> Lz_exact : 1.14966e-03 m
#   --> h_max resolution : 1.06803e-05 m
# #DoFs = 209088 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0059 ---
# coeff gamma =  0.0029406990681020632
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 2.93e-03
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 26/4096 | S_i:8.4, L:3.0λ, p:1.8, n//:8.07, ne:1.0e+18
#
#
# --- delta = 145882.74901681356 ---
# --- B_stix = -253.0834628528363, S = 1.005989319690279, C_stix = -20336.07818829146 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 1.77658e+01, n_perp_m = 1.00000e-03
#   --> lambda_perp : 4.56072e-03 m, lambda_para = 1.00463e-02 m
#   --> Lx_plm = 1.36937e-02 m, Lx_tot = 2.28151e-02 m
#   --> Lz_exact: 1.00463e-02 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 1.77481e+01, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 4.56528e-03 m, lambda_para = 1.00463e-02 m
#   --> Lx_plm = 1.36937e-02 m, Lx_tot = 2.28151e-02 m
#   --> Lz_exact : 1.00463e-02 m
#   --> h_max resolution : 5.70660e-04 m
# #DoFs = 15320 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.2421 ---
# coeff gamma =  0.10797416365916568
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 1.09e-01
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 27/4096 | S_i:2.4, L:5.7λ, p:2.3, n//:38.46, ne:1.7e+18
#
#
# --- delta = 227211858.93743515 ---
# --- B_stix = -12087.100824099956, S = 1.0102404225711497, C_stix = -20072908.090292875 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 1.15943e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 6.98838e-04 m, lambda_para = 2.10680e-03 m
#   --> Lx_plm = 3.99225e-03 m, Lx_tot = 5.38992e-03 m
#   --> Lz_exact: 2.10680e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 1.15836e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 6.99481e-04 m, lambda_para = 2.10680e-03 m
#   --> Lx_plm = 3.99225e-03 m, Lx_tot = 5.38992e-03 m
#   --> Lz_exact : 2.10680e-03 m
#   --> h_max resolution : 8.74351e-05 m
# #DoFs = 32655 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.2641 ---
# coeff gamma =  0.11666292057425537
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 1.17e-01
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 28/4096 | S_i:1.6, L:4.3λ, p:2.2, n//:75.71, ne:7.1e+18
#
#
# --- delta = 57280586786.27285 ---
# --- B_stix = -227390.29608010623, S = 1.0419325459887236, C_stix = -1337476225.3886836 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 4.73255e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 1.71208e-04 m, lambda_para = 1.07017e-03 m
#   --> Lx_plm = 7.34015e-04 m, Lx_tot = 1.07643e-03 m
#   --> Lz_exact: 1.07017e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 4.72860e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 1.71351e-04 m, lambda_para = 1.07017e-03 m
#   --> Lx_plm = 7.34015e-04 m, Lx_tot = 1.07643e-03 m
#   --> Lz_exact : 1.07017e-03 m
#   --> h_max resolution : 2.14189e-05 m
# #DoFs = 54955 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0136 ---
# coeff gamma =  0.006745479655591125
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 6.78e-03
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 29/4096 | S_i:1.1, L:7.2λ, p:1.9, n//:95.20, ne:1.7e+19
#
#
# --- delta = 780603222202.4539 ---
# --- B_stix = -863619.9461275559, S = 1.0979080059566806, C_stix = -7915920702.026241 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 8.92001e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 9.08350e-05 m, lambda_para = 8.51125e-04 m
#   --> Lx_plm = 6.57944e-04 m, Lx_tot = 8.39615e-04 m
#   --> Lz_exact: 8.51125e-04 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 8.91286e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 9.09079e-05 m, lambda_para = 8.51125e-04 m
#   --> Lx_plm = 6.57944e-04 m, Lx_tot = 8.39615e-04 m
#   --> Lz_exact : 8.51125e-04 m
#   --> h_max resolution : 1.13635e-05 m
# #DoFs = 122688 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0039 ---
# coeff gamma =  0.0019215406365748278
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 1.89e-03
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 30/4096 | S_i:3.3, L:4.7λ, p:2.6, n//:32.78, ne:7.4e+17
#
#
# --- delta = 21997156.020117186 ---
# --- B_stix = -2533.0160305055074, S = 1.0043857446492173, C_stix = -3878237.4929965236 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 5.99649e+01, n_perp_m = 1.00000e-03
#   --> lambda_perp : 1.35121e-03 m, lambda_para = 2.47143e-03 m
#   --> Lx_plm = 6.39171e-03 m, Lx_tot = 9.09413e-03 m
#   --> Lz_exact: 2.47143e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 5.99002e+01, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 1.35267e-03 m, lambda_para = 2.47143e-03 m
#   --> Lx_plm = 6.39171e-03 m, Lx_tot = 9.09413e-03 m
#   --> Lz_exact : 2.47143e-03 m
#   --> h_max resolution : 1.69083e-04 m
# #DoFs = 17997 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 2.2784 ---
# coeff gamma =  0.38995215632646363
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 3.78e-01
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 31/4096 | S_i:6.2, L:8.5λ, p:1.7, n//:13.74, ne:4.2e+18
#
#
# --- delta = 21397788.859148722 ---
# --- B_stix = -4240.935191050921, S = 1.024744428200558, C_stix = -832465.5081185705 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 6.57746e+01, n_perp_m = 1.00000e-03
#   --> lambda_perp : 1.23186e-03 m, lambda_para = 5.89728e-03 m
#   --> Lx_plm = 1.04514e-02 m, Lx_tot = 1.29152e-02 m
#   --> Lz_exact: 5.89728e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 6.57182e+01, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 1.23291e-03 m, lambda_para = 5.89728e-03 m
#   --> Lx_plm = 1.04514e-02 m, Lx_tot = 1.29152e-02 m
#   --> Lz_exact : 5.89728e-03 m
#   --> h_max resolution : 1.54114e-04 m
# #DoFs = 71177 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0245 ---
# coeff gamma =  0.012089272063315214
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 1.19e-02
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 32/4096 | S_i:0.9, L:1.5λ, p:2.8, n//:50.99, ne:9.2e+18
#
#
# --- delta = 19726526143.943794 ---
# --- B_stix = -134970.643139059, S = 1.0542626835738675, C_stix = -357940117.3186889 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 3.61418e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 2.24186e-04 m, lambda_para = 1.58897e-03 m
#   --> Lx_plm = 3.45828e-04 m, Lx_tot = 7.94201e-04 m
#   --> Lz_exact: 1.58897e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 3.61120e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 2.24372e-04 m, lambda_para = 1.58897e-03 m
#   --> Lx_plm = 3.45828e-04 m, Lx_tot = 7.94201e-04 m
#   --> Lz_exact : 1.58897e-03 m
#   --> h_max resolution : 2.80465e-05 m
# #DoFs = 34721 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.1342 ---
# coeff gamma =  0.0628644288136486
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 6.29e-02
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 33/4096 | S_i:0.9, L:7.6λ, p:2.4, n//:30.79, ne:7.5e+18
#
#
# --- delta = 1752611873.1467285 ---
# --- B_stix = -39886.21386138003, S = 1.0443975376719608, C_stix = -38706960.500747025 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 1.97832e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 4.09564e-04 m, lambda_para = 2.63165e-03 m
#   --> Lx_plm = 3.10477e-03 m, Lx_tot = 3.92390e-03 m
#   --> Lz_exact: 2.63165e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 1.97667e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 4.09906e-04 m, lambda_para = 2.63165e-03 m
#   --> Lx_plm = 3.10477e-03 m, Lx_tot = 3.92390e-03 m
#   --> Lz_exact : 2.63165e-03 m
#   --> h_max resolution : 5.12382e-05 m
# #DoFs = 87338 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0133 ---
# coeff gamma =  0.006624708297855843
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 6.55e-03
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 34/4096 | S_i:5.9, L:4.4λ, p:2.1, n//:92.77, ne:1.6e+18
#
#
# --- delta = 6702898027.271382 ---
# --- B_stix = -64494.99946374228, S = 1.0095528194510675, C_stix = -629806836.859252 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 2.69241e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 3.00939e-04 m, lambda_para = 8.73365e-04 m
#   --> Lx_plm = 1.32334e-03 m, Lx_tot = 1.92522e-03 m
#   --> Lz_exact: 8.73365e-04 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 2.68991e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 3.01218e-04 m, lambda_para = 8.73365e-04 m
#   --> Lx_plm = 1.32334e-03 m, Lx_tot = 1.92522e-03 m
#   --> Lz_exact : 8.73365e-04 m
#   --> h_max resolution : 3.76522e-05 m
# #DoFs = 26287 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.1039 ---
# coeff gamma =  0.049404565887774504
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 4.90e-02
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 35/4096 | S_i:3.6, L:8.8λ, p:2.6, n//:62.91, ne:9.4e+17
#
#
# --- delta = 478382362.0987433 ---
# --- B_stix = -13914.092601575507, S = 1.005550370417425, C_stix = -70802119.30490035 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 1.33395e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 6.07406e-04 m, lambda_para = 1.28790e-03 m
#   --> Lx_plm = 5.35568e-03 m, Lx_tot = 6.57049e-03 m
#   --> Lz_exact: 1.28790e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 1.33260e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 6.08023e-04 m, lambda_para = 1.28790e-03 m
#   --> Lx_plm = 5.35568e-03 m, Lx_tot = 6.57049e-03 m
#   --> Lz_exact : 1.28790e-03 m
#   --> h_max resolution : 7.60029e-05 m
# #DoFs = 32645 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.3691 ---
# coeff gamma =  0.1557824923200969
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 1.51e-01
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 36/4096 | S_i:1.1, L:1.2λ, p:1.8, n//:25.22, ne:4.1e+19
#
#
# --- delta = 23834689638.17873 ---
# --- B_stix = -152804.8204238996, S = 1.2443718935612043, C_stix = -97514355.61788782 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 3.51328e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 2.30625e-04 m, lambda_para = 3.21302e-03 m
#   --> Lx_plm = 2.77949e-04 m, Lx_tot = 7.39198e-04 m
#   --> Lz_exact: 3.21302e-03 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 3.51066e+02, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 2.30797e-04 m, lambda_para = 3.21302e-03 m
#   --> Lx_plm = 2.77949e-04 m, Lx_tot = 7.39198e-04 m
#   --> Lz_exact : 3.21302e-03 m
#   --> h_max resolution : 2.88497e-05 m
# #DoFs = 60422 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.3785 ---
# coeff gamma =  0.15912698005137474
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 1.59e-01
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 37/4096 | S_i:1.6, L:9.2λ, p:1.6, n//:6.07, ne:9.6e+18
#
#
# --- delta = 4114811.602955668 ---
# --- B_stix = -1952.9188703098596, S = 1.0570271554198467, C_stix = -71171.18216887384 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 4.33971e+01, n_perp_m = 1.00000e-03
#   --> lambda_perp : 1.86706e-03 m, lambda_para = 1.33477e-02 m
#   --> Lx_plm = 1.72104e-02 m, Lx_tot = 2.09446e-02 m
#   --> Lz_exact: 1.33477e-02 m
#
# [MESH BUILDER] :
#   --> SW n_perp_p : 4.33614e+01, n_perp_m = 1.00000e-03
#   --> SW lambda_perp : 1.86860e-03 m, lambda_para = 1.33477e-02 m
#   --> Lx_plm = 1.72104e-02 m, Lx_tot = 2.09446e-02 m
#   --> Lz_exact : 1.33477e-02 m
#   --> h_max resolution : 2.33574e-04 m
# #DoFs = 113881 (= number of mesh points).
# --- Solving the 3D vector linear system ---
# --- SWR = 1.0053 ---
# coeff gamma =  0.0026442489002171067
# --- System solved ---
#   --> FEM Solve Successful | Gamma = 2.55e-03
# --- Run ok & data saved correctly ---
#
#
#
#
# Run 38/4096 | S_i:2.2, L:2.8λ, p:2.9, n//:68.06, ne:4.0e+18
#
#
# --- delta = 12029785077.839205 ---
# --- B_stix = -100199.04229764311, S = 1.0237847830478248, C_stix = -485926591.561132 ---
#
# [Run PMLs Scan] :
#   --> n_perp_p : 3.20159e+02, n_perp_m = 1.00000e-03
#   --> lambda_perp : 2.53077e-04 m, lambda_para = 1.19058e-03 m
#   --> Lx_plm = 7.00608e-04 m, Lx_tot = 1.20676e-03 m
#   --> Lz_exact: 1.19058e-03 m

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from Post_Process_V3_Explore_Data import PMLDataExplorer

explorer_data_file = "/Home/RB286887/LH_coupling_code_remi/LH_2D_Coupling___V3/Simulation_Results/Run_20260520_161645/PML_scan_all_param_dataset.h5"

# explorer_data_file = run_folder_tot_path + "/" + h5_file_path
print(explorer_data_file)
explorer = PMLDataExplorer(explorer_data_file)

display(explorer.df.describe())

# %%
explorer.plot_universal_scatter(
    x_var = 'S_imag', 
    y_var='Gamma_E', 
    color_var='n_para',
    filter_query="Gamma_S < 0.0005"
)

# %%
import seaborn as sns 
import pandas as pd
import h5py

#print(df.keys())
with h5py.File(explorer_data_file, 'r') as h5f:
    data_dict = {key: h5f[key][:] for key in h5f.keys()}

df = pd.DataFrame(data_dict)
df = df.query('Gamma_E < 0.99').copy()
 
corr_matrix = df[['Gamma_E', 'S_real', 'S_imag', 'p_degree', 'L_pml_ratio', 'CPU_Time', 'n_para', 'n_e']].corr(method='spearman')

mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

# sns.heatmap(corr_matrix, cmap='coolwarm', vmin=-1, vmax=1, square=True, linewidth=.5)

# %%
best_run_df = df.query('Gamma_E < 0.0003')
# sns.pairplot(best_run_df, vars=['Gamma_E', 'S_real', 'S_imag', 'L_pml_ratio', 'n_para', 'n_e'], diag_kind='kde', plot_kws={'alpha':0.6})
# plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import Matern, WhiteKernel, ConstantKernel as C
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# Load clean dataset
clean_df = df.query("0 < Gamma_E < 0.90").copy()
clean_df['n_e_log'] = np.log10(clean_df['n_e']) 
features = ['S_imag', 'L_pml_ratio', 'S_real', 'p_degree', 'n_para', 'n_e_log']

X = clean_df[features].values              # X = inputs of the model 
Y = np.log10(clean_df['Gamma_E'].values)   # Y = outputs
 
print(f"Valid runs for training: {len(clean_df)}")

# Standardize Features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y, train_size=2000, random_state=42)

# Generating the kernel
physics_kernel = C(1.0) * Matern(length_scale=[1.0] * len(features), nu=2.5)
noise_kernel = WhiteKernel(noise_level=0.1, noise_level_bounds=(1e-3, 1.0))
full_kernel = physics_kernel + noise_kernel

# GPR Configuration
gpr = GaussianProcessRegressor(
    kernel=full_kernel, 
    n_restarts_optimizer=10, 
    normalize_y=True, 
    random_state=42
)

print("Training Noise-Adaptive GPR (This may take 1-2 minutes)...")
gpr.fit(X_train, y_train)

# 8. Validation
y_pred_test = gpr.predict(X_test)
r2 = r2_score(y_test, y_pred_test)

print(f"\n[VALIDATION] GPR R^2 Score on unseen data: {r2:.4f}")

# %%
if r2 > 0.85:
    print("\n[SUCCESS] The model successfully mapped the physics and ignored the mode-mixing noise.")
    
    # Print the learned length scales
    learned_scales = gpr.kernel_.k1.k2.length_scale
    print("\nLearned Length Scales (Smaller = Higher Physical Impact):")
    for name, scale in zip(features, learned_scales):
        print(f"{name:12}: {scale:.2f}")

# %%
# mesh_conv_h5_filepath = pp_run.run_mesh_convergence(solver, cfg, run_folder_tot_path)

# %%
# pp_plot.plot_mesh_convergence(mesh_conv_h5_filepath, run_folder_tot_path)

# %%
# Pour faire des boucles sur les params de config_dict

cfg.DOMAIN['Lx_plasma'] = 30.
print(cfg.DOMAIN['Lx_plasma'] )
